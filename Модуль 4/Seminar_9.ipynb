# %% [markdown]
# # Построение простейших графиков, знакомство с библиотекой matplotlib

# %% [markdown]
# В рамках данного занятия столкнёмся с реальными экспериментальными данными, отработаем работу с двумерными графиками и затронем другие виды

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# _Упражнение 9.1_

# %% [markdown]
# Из предложенных _.DAT_ файлов сформируйте хранилище в удобном для дальнейшей работы виде. Нам потребуются столбцы с температурой, магнитным полем и магнитным моментом

# %%
def ...
...
storage_pandas = ...

# %% [markdown]
# _Упражнение 9.2_

# %% [markdown]
# На основе только что сформированного хранилища постройте кривые намагниченности для каждого файла на одном графике. Уберите линии, выбивающиеся из общей картины

# %%
...

# %% [markdown]
# _Упражнение 9.3_

# %% [markdown]
# Теперь те же графики разбейте на 2 отдельных окна, чтобы слева был график при **T = 5**, а справа при **Т = 30**

# %%
...

# %% [markdown]
# _Упражнение 9.4_

# %% [markdown]
# Найдите максимальные значения намагниченностей и отстройте их на столбчатой диаграмме, указав температуры

# %%
...

# %% [markdown]
# **Задание 4.1** Пусть имеется детектор зараяженных частиц. При попадании частицы, возникает тепловое пятно, постепенно рассеивающееся по пластине. Её размер 10 на 20 _мм_ с размером чувствительной ячейки 100 на 100 _мкм_
#
# На детектор падают две одинаковые частицы с разницей в 0.2 секунды. Их след задаётся функцией `Particle(x, y, t)`
#
# Постройте тепловые карты в два промежутка времени:
# 1) Через 0.1 секунды после попадания первой частицы
# 2) Ещё через 0.3 секунды

# %%
import numpy as np
import matplotlib.pyplot as plt

X, Y = ...

Particle = lambda x, y, t: 5*np.exp(-((X-x)**2+(Y-y)**2)/2/np.exp(t/0.4)**2)*np.exp(-t/0.3)/np.sqrt(2*np.pi)/np.exp(t/0.4)

...
